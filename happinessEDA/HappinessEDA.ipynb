# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Reading the data
df = pd.read_csv('world-happiness-report-2021.csv')

# %%
# A brief overview
df.head(15)
# Out:
#    Country name            Regional indicator  Ladder score  \
# 0       Finland                Western Europe         7.842
# 1       Denmark                Western Europe         7.620
# 2   Switzerland                Western Europe         7.571
# 3       Iceland                Western Europe         7.554
# 4   Netherlands                Western Europe         7.464
# 5        Norway                Western Europe         7.392
# 6        Sweden                Western Europe         7.363
# 7    Luxembourg                Western Europe         7.324
# 8   New Zealand         North America and ANZ         7.277
# 9       Austria                Western Europe         7.268
# 10    Australia         North America and ANZ         7.183
# 11       Israel  Middle East and North Africa         7.157
# 12      Germany                Western Europe         7.155
# 13       Canada         North America and ANZ         7.103
# 14      Ireland                Western Europe         7.085
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                            0.032         7.904         7.780
# 1                            0.035         7.687         7.552
# 2                            0.036         7.643         7.500
# 3                            0.059         7.670         7.438
# 4                            0.027         7.518         7.410
# 5                            0.035         7.462         7.323
# 6                            0.036         7.433         7.293
# 7                            0.037         7.396         7.252
# 8                            0.040         7.355         7.198
# 9                            0.036         7.337         7.198
# 10                           0.041         7.265         7.102
# 11                           0.034         7.224         7.090
# 12                           0.040         7.232         7.077
# 13                           0.042         7.185         7.021
# 14                           0.040         7.164         7.006
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                  10.775           0.954                   72.000
# 1                  10.933           0.954                   72.700
# 2                  11.117           0.942                   74.400
# 3                  10.878           0.983                   73.000
# 4                  10.932           0.942                   72.400
# 5                  11.053           0.954                   73.300
# 6                  10.867           0.934                   72.700
# 7                  11.647           0.908                   72.600
# 8                  10.643           0.948                   73.400
# 9                  10.906           0.934                   73.300
# 10                 10.796           0.940                   73.900
# 11                 10.575           0.939                   73.503
# 12                 10.873           0.903                   72.500
# 13                 10.776           0.926                   73.800
# 14                 11.342           0.947                   72.400
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                          0.949      -0.098                      0.186
# 1                          0.946       0.030                      0.179
# 2                          0.919       0.025                      0.292
# 3                          0.955       0.160                      0.673
# 4                          0.913       0.175                      0.338
# 5                          0.960       0.093                      0.270
# 6                          0.945       0.086                      0.237
# 7                          0.907      -0.034                      0.386
# 8                          0.929       0.134                      0.242
# 9                          0.908       0.042                      0.481
# 10                         0.914       0.159                      0.442
# 11                         0.800       0.031                      0.753
# 12                         0.875       0.011                      0.460
# 13                         0.915       0.089                      0.415
# 14                         0.879       0.077                      0.363
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                       2.43                             1.446
# 1                       2.43                             1.502
# 2                       2.43                             1.566
# 3                       2.43                             1.482
# 4                       2.43                             1.501
# 5                       2.43                             1.543
# 6                       2.43                             1.478
# 7                       2.43                             1.751
# 8                       2.43                             1.400
# 9                       2.43                             1.492
# 10                      2.43                             1.453
# 11                      2.43                             1.376
# 12                      2.43                             1.480
# 13                      2.43                             1.447
# 14                      2.43                             1.644
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                          1.106                                  0.741
# 1                          1.108                                  0.763
# 2                          1.079                                  0.816
# 3                          1.172                                  0.772
# 4                          1.079                                  0.753
# 5                          1.108                                  0.782
# 6                          1.062                                  0.763
# 7                          1.003                                  0.760
# 8                          1.094                                  0.785
# 9                          1.062                                  0.782
# 10                         1.076                                  0.801
# 11                         1.074                                  0.788
# 12                         0.993                                  0.757
# 13                         1.044                                  0.798
# 14                         1.092                                  0.753
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                        0.691                     0.124
# 1                                        0.686                     0.208
# 2                                        0.653                     0.204
# 3                                        0.698                     0.293
# 4                                        0.647                     0.302
# 5                                        0.703                     0.249
# 6                                        0.685                     0.244
# 7                                        0.639                     0.166
# 8                                        0.665                     0.276
# 9                                        0.640                     0.215
# 10                                       0.647                     0.291
# 11                                       0.509                     0.208
# 12                                       0.600                     0.195
# 13                                       0.648                     0.246
# 14                                       0.606                     0.238
#
#     Explained by: Perceptions of corruption  Dystopia + residual
# 0                                     0.481                3.253
# 1                                     0.485                2.868
# 2                                     0.413                2.839
# 3                                     0.170                2.967
# 4                                     0.384                2.798
# 5                                     0.427                2.580
# 6                                     0.448                2.683
# 7                                     0.353                2.653
# 8                                     0.445                2.612
# 9                                     0.292                2.784
# 10                                    0.317                2.598
# 11                                    0.119                3.083
# 12                                    0.306                2.824
# 13                                    0.335                2.585
# 14                                    0.367                2.384

# %%
# Are any null values?
df.isna().sum().sum()
# Out:
# 0

# %%
# Are any duplicated values?
df.duplicated().sum()
# Out:
# 0

# %%
#Dataset's dimensions
df.shape
# Out:
# (149, 20)

# %%
#Dataset's basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
#  9   Freedom to make life choices                149 non-null    float64
#  10  Generosity                                  149 non-null    float64
#  11  Perceptions of corruption                   149 non-null    float64
#  12  Ladder score in Dystopia                    149 non-null    float64
#  13  Explained by: Log GDP per capita            149 non-null    float64
#  14  Explained by: Social support                149 non-null    float64
#  15  Explained by: Healthy life expectancy       149 non-null    float64
#  16  Explained by: Freedom to make life choices  149 non-null    float64
#  17  Explained by: Generosity                    149 non-null    float64
#  18  Explained by: Perceptions of corruption     149 non-null    float64
#  19  Dystopia + residual                         149 non-null    float64
# dtypes: float64(18), object(2)
# memory usage: 23.4+ KB

# %%
#Taking a subset of the df
df1 = df.iloc[:, [0, 1, 2, 6, 7, 8, 9, 10, 11]]

# %%
df1.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df1.describe().T
# Out:
#                               count       mean       std     min     25%  \
# Ladder score                  149.0   5.532839  1.073924   2.523   4.852
# Logged GDP per capita         149.0   9.432208  1.158601   6.635   8.541
# Social support                149.0   0.814745  0.114889   0.463   0.750
# Healthy life expectancy       149.0  64.992799  6.762043  48.478  59.802
# Freedom to make life choices  149.0   0.791597  0.113332   0.382   0.718
# Generosity                    149.0  -0.015134  0.150657  -0.288  -0.126
# Perceptions of corruption     149.0   0.727450  0.179226   0.082   0.667
#
#                                  50%     75%     max
# Ladder score                   5.534   6.255   7.842
# Logged GDP per capita          9.569  10.421  11.647
# Social support                 0.832   0.905   0.983
# Healthy life expectancy       66.603  69.600  76.953
# Freedom to make life choices   0.804   0.877   0.970
# Generosity                    -0.036   0.079   0.542
# Perceptions of corruption      0.781   0.845   0.939

# %%
#Relation between happiness and GDP
sns.set_style("whitegrid")
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Logged GDP per capita'], y=df['Ladder score'], hue=df['Regional indicator'])
plt.legend(loc='best',fontsize=10)
plt.title('Dependence of GDP per capita on Happiness',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Dependence of GDP per capita on Happiness')

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Healthy life expectancy'], y=df['Ladder score'], hue=df['Regional indicator'])
plt.legend(loc='best',fontsize=10)
plt.title('Dependence of Healthy life expectancy on Happiness',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Dependence of Healthy life expectancy on Happiness')

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Freedom to make life choices'], y=df['Ladder score'], hue=df['Regional indicator'])
plt.legend(loc='best',fontsize=10)
plt.title('Dependence of Freedom to make life choices on Happiness',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Dependence of Freedom to make life choices on Happiness')

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Perceptions of corruption'], y=df['Ladder score'], hue=df['Regional indicator'])
plt.legend(loc='best',fontsize=10)
plt.title('Dependence of Perceptions of corruption on Happiness',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Dependence of Perceptions of corruption on Happiness')

# %%
# Create a pair plot
sns.pairplot(df1, hue='Regional indicator')

# %%
plt.figure(figsize=(6,5))
sns.heatmap(df1.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
# Regionwise Happiness Score
sns.set_style("whitegrid")
plt.figure(figsize=(15,4))
sns.barplot(data=df1,y=df['Regional indicator'],x=df['Ladder score'])
plt.title('Happiness Score based on Geographic Region')
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(5,25))
sns.barplot(data=df1,y=df['Country name'],x=df['Ladder score'])
plt.title('Happiness Score per country')
plt.show()

# %%
# Join Plots
sns.jointplot(x=df1['Ladder score'], y=df1['Healthy life expectancy'],
              data=df1,kind='kde') # king =␣['kde','hex','reg']

# %%
sns.jointplot(x=df1['Ladder score'], y=df1['Freedom to make life choices'],
              data=df1, kind='hex') # king =␣['kde','hex','reg']

# %%
sns.jointplot(x=df1['Ladder score'], y=df1['Logged GDP per capita'],
              data=df1, kind='reg') # king =␣['kde','hex','reg']

# %%
# Create the binary variable
df1['sadness'] = df1['Ladder score'].apply(lambda x: 'not happy' if x < 6 else 'happy')
# Out:
# C:\Users\maryk\AppData\Local\Temp\ipykernel_20500\1986295225.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['sadness'] = df1['Ladder score'].apply(lambda x: 'not happy' if x < 6 else 'happy')

# %%
df1['sadness']
# Out:
# 0          happy
# 1          happy
# 2          happy
# 3          happy
# 4          happy
#          ...
# 144    not happy
# 145    not happy
# 146    not happy
# 147    not happy
# 148    not happy
# Name: sadness, Length: 149, dtype: object

# %%
df1.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'is_not_happy', 'sadness'],
#       dtype='object')

# %%
#boxplot
selected_categories = ['Western Europe', 'Latin America and Caribbean', 'Middle East and North Africa']
filt = df1[df1['Regional indicator'].isin(selected_categories)]
plt.figure(figsize=(10,5))
sns.boxplot(x=filt['Regional indicator'], y=filt['Ladder score'], data=filt, hue='sadness')
# Out:
# <AxesSubplot:xlabel='Regional indicator', ylabel='Ladder score'>

# %%
# Violin plot
selected_categories = ['Western Europe', 'Latin America and Caribbean', 'Middle East and North Africa']
filt = df1[df1['Regional indicator'].isin(selected_categories)]
plt.figure(figsize=(10,5))
sns.violinplot(x=filt['Regional indicator'], y=filt['Ladder score'], data=filt, hue='sadness')
# Out:
# <AxesSubplot:xlabel='Regional indicator', ylabel='Ladder score'>

# %%
#Pair grid
sns.set(style='ticks')
sns.pairplot(df1, hue='sadness')
